# %% [markdown]
# # Chapter 04: First Scraper Practice
#
# 目标：参照书里的第一章爬虫示例，自己手敲一遍最小网页请求和 HTML 解析流程。

# %% [markdown]
# ## 1. 导入工具
#
# 先只用书里前期会出现的基础工具。

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %% [markdown]
# ## 2. 请求网页
#
# 先敲一遍最小版本，确认能拿到页面。

# %%
html = urlopen("http://www.pythonscraping.com/pages/page1.html")
html

# %% [markdown]
# ## 3. 解析标题
#
# 这里先只提取一个字段，避免一开始东西太多。

# %%
bs = BeautifulSoup(html.read(), "html.parser")
bs.h1
# Out:
# <h1>An Interesting Title</h1>

# %% [markdown]
# ## 4. 自己改一改
#
# 可以试着输出 `bs.html.body.h1`、`bs.body.h1`、`bs.html.h1`，观察结果是否一样。

# %%
# 在这里写你的实验代码
bs.html.body.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bs.body.h1
# Out:
# <h1>An Interesting Title</h1>

# %%
bs.html.h1
# Out:
# <h1>An Interesting Title</h1>
