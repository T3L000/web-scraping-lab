# %%
html = urlopen('http://www.pythonscraping.com/pages/page1.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 html = urlopen('http://www.pythonscraping.com/pages/page1.html')
#
# NameError: name 'urlopen' is not defined
